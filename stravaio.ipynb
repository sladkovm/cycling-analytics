# %%
# %load_ext autoreload
# %autoreload 2
import os
import dotenv
from stravaio import StravaIO
import numpy as np
import pandas as pd
dotenv.load_dotenv()
access_token = os.getenv('ACCESS_TOKEN')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from plotly.offline import iplot, init_notebook_mode
import plotly
import plotly.graph_objs as go
import plotly_express as px
# init_notebook_mode(connected=True)

# %%
plotly.__version__
# Out:
# '3.10.0'

# %%
# Some constants to be used throughout the calculations
ATHLETE_ID = 1202065

# %%
client = StravaIO(access_token)

# %% [markdown]
# # Get information about the athlete

# %% [markdown]
# ## Option 1:  Get the athlete info from strava

# %%
athlete = client.get_logged_in_athlete()
athlete
# Out:
# {
#   "id": 1202065,
#   "resource_state": 3,
#   "firstname": "Maksym",
#   "lastname": "Sladkov",
#   "profile_medium": "https://dgalywyr863hv.cloudfront.net/pictures/athletes/1202065/329723/1/medium.jpg",
#   "profile": "https://dgalywyr863hv.cloudfront.net/pictures/athletes/1202065/329723/1/large.jpg",
#   "city": "Graz",
#   "state": "Styria",
#   "country": "Austria",
#   "sex": "M",
#   "friend": null,
#   "follower": null,
#   "premium": false,
#   "summit": false,
#   "created_at": "2012-10-13T14:40:18Z",
#   "updated_at": "2019-02-16T16:17:09Z",
#   "follower_count": 292,
#   "friend_count": 112,
#   "mutual_friend_count": 0,
#   "measurement_preference": "meters",
#   "ftp": 240,
#   "weight": 73.102,
#   "clubs": [
#     {
#       "id": 22072,
#       "resource_state": 2,
#       "name": "Racefietsblog.nl",
#       "profile_medium": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/22072/479694/5/medium.jpg",
#       "cover_photo": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/22072/4996645/7/large.jpg",
#       "cover_photo_small": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/22072/4996645/7/small.jpg",
#       "sport_type": "cycling",
#       "city": "Amsterdam",
#       "state": "Noord-Holland",
#       "country": "Nederland",
#       "private": false,
#       "member_count": 0,
#       "featured": false,
#       "verified": true,
#       "url": "racefietsblog"
#     },
#     {
#       "id": 38013,
#       "resource_state": 2,
#       "name": "GCN",
#       "profile_medium": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/38013/1033989/3/medium.jpg",
#       "cover_photo": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/38013/5381044/8/large.jpg",
#       "cover_photo_small": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/38013/5381044/8/small.jpg",
#       "sport_type": "cycling",
#       "city": "Bath",
#       "state": "England",
#       "country": "United Kingdom",
#       "private": false,
#       "member_count": 0,
#       "featured": false,
#       "verified": true,
#       "url": "globalcyclingnetwork"
#     },
#     {
#       "id": 7720,
#       "resource_state": 2,
#       "name": "Cycling Team Wielertoerist",
#       "profile_medium": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/7720/114627/1/medium.jpg",
#       "cover_photo": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/7720/4466055/2/large.jpg",
#       "cover_photo_small": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/7720/4466055/2/small.jpg",
#       "sport_type": "other",
#       "city": "",
#       "state": "",
#       "country": "Nederland",
#       "private": true,
#       "member_count": 0,
#       "featured": false,
#       "verified": false,
#       "url": "cycling-team-wielertoerist"
#     },
#     {
#       "id": 30331,
#       "resource_state": 2,
#       "name": "Die_Grazer_Stravisten",
#       "profile_medium": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/30331/4011449/1/medium.jpg",
#       "cover_photo": null,
#       "cover_photo_small": null,
#       "sport_type": "cycling",
#       "city": "Graz",
#       "state": "Steiermark",
#       "country": "\u00d6sterreich",
#       "private": false,
#       "member_count": 0,
#       "featured": false,
#       "verified": false,
#       "url": "die_grazer_stravisten"
#     },
#     {
#       "id": 457249,
#       "resource_state": 2,
#       "name": "Teamgeist",
#       "profile_medium": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/457249/9547707/3/medium.jpg",
#       "cover_photo": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/457249/9515160/5/large.jpg",
#       "cover_photo_small": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/457249/9515160/5/small.jpg",
#       "sport_type": "cycling",
#       "city": "Graz",
#       "state": "Steiermark",
#       "country": "\u00d6sterreich",
#       "private": false,
#       "member_count": 0,
#       "featured": false,
#       "verified": false,
#       "url": "teamgeist"
#     },
#     {
#       "id": 321004,
#       "resource_state": 2,
#       "name": "Strava Austria",
#       "profile_medium": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/321004/7524373/2/medium.jpg",
#       "cover_photo": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/321004/7524397/13/large.jpg",
#       "cover_photo_small": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/321004/7524397/13/small.jpg",
#       "sport_type": "cycling",
#       "city": "",
#       "state": "",
#       "country": "\u00d6sterreich",
#       "private": false,
#       "member_count": 0,
#       "featured": false,
#       "verified": false,
#       "url": "stravaaustria"
#     },
#     {
#       "id": 435594,
#       "resource_state": 2,
#       "name": "The Sufferfest",
#       "profile_medium": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/435594/8604071/3/medium.jpg",
#       "cover_photo": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/435594/8604076/19/large.jpg",
#       "cover_photo_small": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/435594/8604076/19/small.jpg",
#       "sport_type": "cycling",
#       "city": "",
#       "state": "",
#       "country": "United States",
#       "private": false,
#       "member_count": 0,
#       "featured": false,
#       "verified": true,
#       "url": "thesufferfest"
#     },
#     {
#       "id": 496284,
#       "resource_state": 2,
#       "name": "Do The Plan With Dan",
#       "profile_medium": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/496284/11146568/1/medium.jpg",
#       "cover_photo": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/496284/11146631/4/large.jpg",
#       "cover_photo_small": "https://dgalywyr863hv.cloudfront.net/pictures/clubs/496284/11146631/4/small.jpg",
#       "sport_type": "cycling",
#       "city": "Reno",
#       "state": "Nevada",
#       "country": "United States",
#       "private": false,
#       "member_count": 0,
#       "featured": false,
#       "verified": false,
#       "url": "dotheplanwithdan"
#     }
#   ],
#   "bikes": [
#     {
#       "id": "b1245851",
#       "resource_state": 2,
#       "primary": false,
#       "name": "Cervelo R3",
#       "distance": 21610871.0
#     },
#     {
#       "id": "b1010908",
#       "resource_state": 2,
#       "primary": false,
#       "name": "Cube Reaction Pro 2012",
#       "distance": 450683.0
#     },
#     {
#       "id": "b3770749",
#       "resource_state": 2,
#       "primary": false,
#       "name": "Elite Turbo Muin ",
#       "distance": 29882.0
#     },
#     {
#       "id": "b2706523",
#       "resource_state": 2,
#       "primary": false,
#       "name": "Other",
#       "distance": 906744.0
#     },
#     {
#       "id": "b1138423",
#       "resource_state": 2,
#       "primary": false,
#       "name": "Puch Hybrid",
#       "distance": 1183915.0
#     },
#     {
#       "id": "b1025530",
#       "resource_state": 2,
#       "primary": false,
#       "name": "Tacx Flow",
#       "distance": 3161360.0
#     },
#     {
#       "id": "b452175",
#       "resource_state": 2,
#       "primary": false,
#       "name": "Wilier La Triestina",
#       "distance": 15695401.0
#     }
#   ],
#   "shoes": [
#     {
#       "id": "g542311",
#       "resource_state": 2,
#       "primary": true,
#       "name": "Saucony Guide 7",
#       "distance": 189283.0
#     }
#   ]
# }

# %% [markdown]
# ## Option 2: Get the athlete from local storage (assuming at was already stored)

# %%
# A generator with a single element will be returned, access the element by calling next()..,
athlete = next(client.local_athletes())
assert athlete['id']==ATHLETE_ID

# %% [markdown]
# # Load athlete activities (last year)

# %% [markdown]
# ## Option 1: load activities from Strava

# %%
# Returns a list of summary activities
activities = client.get_logged_in_athlete_activities(after='last week')
# Out:
# Fetched 3, the latests is on 2019-06-09 11:13:18+00:00

# %%
[a.name for a in activities]
# Out:
# ['G.O.A.T', 'With Antonio', 'Afternoon Ride']

# %%
a = client.get_activity_by_id(id=activities[-1].id)

# %%
a
# Out:
# Activity: 2436304110, Date: 2019-06-09 11:13:18+00:00, Name: Afternoon Ride

# %%
s = client.get_activity_streams(activities[-1].id, athlete_id=athlete.id)
s
# Out:
# Streams for 2436304110
# Keys: ['time', 'distance', 'altitude', 'velocity_smooth', 'heartrate', 'cadence', 'watts', 'temp', 'moving', 'grade_smooth', 'lat', 'lng']
# Access: obj.key

# %%
df = pd.DataFrame(s.to_dict())

# %%
df.head()
# Out:
#    time  distance  altitude  velocity_smooth  heartrate  cadence  watts  temp  \
# 0   165     458.7     389.6              5.0        113       82    131    26
# 1   166     463.3     389.8              4.9        113       80    165    26
# 2   167     467.7     390.0              4.8        113       78    168    26
# 3   168     471.7     390.2              4.5        113       77    178    26
# 4   169     475.8     390.4              4.3        113       78    177    26
#
#    moving  grade_smooth        lat        lng
# 0    True           3.2  47.084871  15.442007
# 1    True           3.4  47.084894  15.442057
# 2    True           4.7  47.084916  15.442106
# 3    True           3.6  47.084932  15.442152
# 4    True           2.5  47.084949  15.442200

# %%
ftp=257
strava_orange = '#fc4c02'
df['color']= 'white'
df.loc[df['watts'] > ftp*0.6, 'color'] = 'grey'
df.loc[df['watts'] > ftp*0.9, 'color'] = strava_orange
df[df['watts']==0] = None
df = df.dropna()

# %%
df.head()
# Out:
#     time  distance  altitude  velocity_smooth  heartrate  cadence  watts  \
# 0  165.0     458.7     389.6              5.0      113.0     82.0  131.0
# 1  166.0     463.3     389.8              4.9      113.0     80.0  165.0
# 2  167.0     467.7     390.0              4.8      113.0     78.0  168.0
# 3  168.0     471.7     390.2              4.5      113.0     77.0  178.0
# 4  169.0     475.8     390.4              4.3      113.0     78.0  177.0
#
#    temp  moving  grade_smooth        lat        lng  color
# 0  26.0     1.0           3.2  47.084871  15.442007  white
# 1  26.0     1.0           3.4  47.084894  15.442057   grey
# 2  26.0     1.0           4.7  47.084916  15.442106   grey
# 3  26.0     1.0           3.6  47.084932  15.442152   grey
# 4  26.0     1.0           2.5  47.084949  15.442200   grey

# %%
out, bins = pd.cut(df.watts, bins=np.arange(0, df.watts.max(), 25), retbins=True)

# %%
bins
# Out:
# array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200., 225., 250.,
#        275., 300., 325., 350., 375., 400., 425., 450.])

# %%
hist = df['watts'].groupby(out).count()

# %%
bin_c = pd.DataFrame({'watts': bins})

# %%
bin_c['color'] = 'white'

# %%
bin_c.loc[bin_c['watts'] > 0.6*ftp, 'color'] = 'grey'
bin_c.loc[bin_c['watts'] > 0.9*ftp, 'color'] = strava_orange

# %%
altitude = go.Scatter(
    x=df.time,
    y=df.altitude,
    fill='tozeroy',
    fillcolor='rgb(30,30,30)',
    line=dict(
        color='rgb(30,30,30)'
    )
)

watts = go.Scattergl(
    x=df.time,
    y=df.watts,
    mode='markers',
    marker=dict(
        color=df['color'],
        size=2
    )
)


watts_b = go.Bar(
    y = bins,
    x = hist,
    orientation='h',
    marker=dict(
        color = bin_c['color']
    )
)



fig = plotly.tools.make_subplots(rows=1, cols=2, shared_yaxes=True)

fig.append_trace(altitude, 1,1)
fig.append_trace(watts, 1,1)
fig.append_trace(watts_b, 1,2)
fig.layout.update(plot_bgcolor='black')
fig.layout.update(xaxis=dict(domain=[0, 0.8]))
fig.layout.update(xaxis2=dict(domain=[0.8, 1.0]))
fig.layout.update(bargap=0)

iplot(fig)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y1 ]
# <div>
#
#
#             <div id="7e2cc39f-c5af-491f-912f-ab123a2854de" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7e2cc39f-c5af-491f-912f-ab123a2854de")) {
#                     Plotly.newPlot(
#                         '7e2cc39f-c5af-491f-912f-ab123a2854de',
#                         [{"fill": "tozeroy", "fillcolor": "rgb(30,30,30)", "line": {"color": "rgb(30,30,30)"}, "type": "scatter", "uid": "e36fb799-8439-4f80-9825-9dd6e60afb5f", "x": [165.0, 166.0, 167.0, 168.0, 169.0, 170.0, 171.0, 172.0, 173.0, 174.0, 175.0, 176.0, 177.0, 178.0, 179.0, 180.0, 181.0, 182.0, 183.0, 184.0, 185.0, 186.0, 187.0, 188.0, 189.0, 190.0, 191.0, 192.0, 193.0, 194.0, 195.0, 196.0, 197.0, 198.0, 199.0, 200.0, 201.0, 202.0, 203.0, 204.0, 205.0, 206.0, 207.0, 208.0, 209.0, 210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 216.0, 217.0, 218.0, 219.0, 220.0, 221.0, 222.0, 223.0, 224.0, 225.0, 226.0, 227.0, 228.0, 229.0, 230.0, 250.0, 251.0, 252.0, 253.0, 254.0, 255.0, 256.0, 257.0, 258.0, 259.0, 260.0, 261.0, 262.0, 263.0, 264.0, 265.0, 266.0, 267.0, 268.0, 269.0, 270.0, 271.0, 272.0, 273.0, 274.0, 275.0, 276.0, 277.0, 282.0, 283.0, 284.0, 285.0, 286.0, 287.0, 288.0, 289.0, 290.0, 291.0, 292.0, 293.0, 294.0, 295.0, 296.0, 297.0, 298.0, 299.0, 300.0, 301.0, 302.0, 303.0, 304.0, 305.0, 306.0, 307.0, 308.0, 309.0, 310.0, 311.0, 312.0, 313.0, 314.0, 315.0, 316.0, 317.0, 318.0, 319.0, 320.0, 321.0, 322.0, 323.0, 324.0, 325.0, 326.0, 327.0, 328.0, 329.0, 330.0, 331.0, 332.0, 333.0, 334.0, 335.0, 336.0, 337.0, 338.0, 339.0, 340.0, 341.0, 342.0, 343.0, 344.0, 345.0, 346.0, 347.0, 348.0, 349.0, 350.0, 351.0, 352.0, 353.0, 354.0, 355.0, 356.0, 357.0, 358.0, 359.0, 360.0, 361.0, 362.0, 363.0, 364.0, 365.0, 366.0, 367.0, 368.0, 369.0, 370.0, 371.0, 372.0, 373.0, 374.0, 375.0, 376.0, 377.0, 378.0, 379.0, 380.0, 381.0, 382.0, 383.0, 384.0, 385.0, 386.0, 387.0, 388.0, 389.0, 390.0, 391.0, 392.0, 393.0, 394.0, 395.0, 396.0, 397.0, 398.0, 399.0, 400.0, 401.0, 402.0, 403.0, 404.0, 405.0, 406.0, 407.0, 408.0, 409.0, 410.0, 411.0, 412.0, 413.0, 414.0, 415.0, 416.0, 417.0, 418.0, 419.0, 420.0, 421.0, 422.0, 423.0, 424.0, 425.0, 426.0, 427.0, 428.0, 429.0, 430.0, 431.0, 432.0, 433.0, 434.0, 435.0, 436.0, 437.0, 438.0, 439.0, 440.0, 441.0, 442.0, 443.0, 444.0, 445.0, 446.0, 447.0, 448.0, 449.0, 450.0, 451.0, 452.0, 453.0, 454.0, 455.0, 456.0, 457.0, 458.0, 459.0, 460.0, 461.0, 462.0, 463.0, 464.0, 465.0, 466.0, 467.0, 468.0, 469.0, 470.0, 471.0, 472.0, 473.0, 474.0, 475.0, 476.0, 477.0, 478.0, 479.0, 480.0, 481.0, 482.0, 483.0, 484.0, 485.0, 486.0, 487.0, 488.0, 489.0, 490.0, 491.0, 492.0, 493.0, 494.0, 495.0, 496.0, 497.0, 498.0, 499.0, 500.0, 501.0, 502.0, 503.0, 504.0, 505.0, 506.0, 507.0, 508.0, 509.0, 510.0, 511.0, 512.0, 513.0, 514.0, 515.0, 516.0, 517.0, 518.0, 519.0, 520.0, 521.0, 522.0, 523.0, 524.0, 525.0, 526.0, 527.0, 528.0, 529.0, 530.0, 531.0, 532.0, 533.0, 534.0, 535.0, 536.0, 537.0, 538.0, 539.0, 540.0, 541.0, 542.0, 543.0, 544.0, 545.0, 546.0, 547.0, 548.0, 549.0, 550.0, 551.0, 552.0, 553.0, 554.0, 555.0, 556.0, 557.0, 558.0, 559.0, 560.0, 561.0, 562.0, 563.0, 564.0, 565.0, 566.0, 567.0, 568.0, 569.0, 570.0, 571.0, 572.0, 573.0, 574.0, 575.0, 576.0, 577.0, 578.0, 579.0, 580.0, 581.0, 582.0, 583.0, 584.0, 585.0, 586.0, 587.0, 588.0, 589.0, 590.0, 591.0, 592.0, 593.0, 594.0, 595.0, 596.0, 597.0, 598.0, 599.0, 600.0, 601.0, 602.0, 603.0, 604.0, 605.0, 606.0, 607.0, 608.0, 609.0, 610.0, 611.0, 612.0, 613.0, 614.0, 615.0, 616.0, 617.0, 618.0, 619.0, 620.0, 621.0, 622.0, 623.0, 624.0, 625.0, 626.0, 627.0, 628.0, 629.0, 630.0, 631.0, 632.0, 633.0, 634.0, 635.0, 636.0, 637.0, 638.0, 639.0, 640.0, 641.0, 642.0, 643.0, 644.0, 645.0, 646.0, 647.0, 648.0, 649.0, 650.0, 651.0, 652.0, 653.0, 654.0, 655.0, 656.0, 657.0, 658.0, 659.0, 660.0, 661.0, 662.0, 663.0, 664.0, 665.0, 666.0, 697.0, 698.0, 699.0, 700.0, 701.0, 702.0, 703.0, 704.0, 705.0, 706.0, 707.0, 708.0, 709.0, 710.0, 711.0, 712.0, 713.0, 714.0, 715.0, 716.0, 717.0, 718.0, 719.0, 720.0, 721.0, 722.0, 723.0, 724.0, 725.0, 726.0, 727.0, 728.0, 729.0, 730.0, 731.0, 732.0, 733.0, 734.0, 735.0, 736.0, 737.0, 738.0, 739.0, 740.0, 741.0, 742.0, 743.0, 744.0, 745.0, 746.0, 747.0, 748.0, 749.0, 750.0, 751.0, 752.0, 753.0, 754.0, 755.0, 762.0, 772.0, 773.0, 774.0, 775.0, 776.0, 777.0, 77 ...

# %%
watts_h
# Out:
# Histogram({
#     'marker': {'color': array(['white', 'grey', 'grey', ..., 'white', '#fc4c02', '#fc4c02'],
#          dtype=object)},
#     'y': array([131., 165., 168., ...,  20., 323., 406.])
# })

# %%
df.color
# Out:
# 'orange'
